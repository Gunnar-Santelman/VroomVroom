# %%
import pandas as pd
import numpy as np
from pathlib import Path

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# data load
base_data = pd.read_csv("./fsae_data/2025/raw-data.csv")

cost_data = pd.read_csv("./fsae_data/2025/fsae_cost_results.csv")
# cost_data = cost_data.drop(columns=["Place", "Car Num", "Penalty", "Score", "Penalty"])
cost_data = cost_data[["Team", "Adjusted Cost"]]
merged_data = pd.merge(base_data, cost_data, on = 'Team', how = "outer")

efficiency_data = pd.read_csv("./fsae_data/2025/fsae_efficiency_results.csv")
#efficiency_data = efficiency_data.drop(columns = ["Place", "Car Num", "Fuel Efficiency Score"])
efficiency_data = efficiency_data[["Team", "Average Adjusted Laptime", "Fuel Efficiency Factor"]]
merged_data = pd.merge(merged_data, efficiency_data, on= 'Team', how = 'outer')

accel_data = pd.read_csv("./fsae_data/2025/fsae_accel_results.csv", index_col=False)
accel_data = accel_data[["Team", "Final Best Time"]]
accel_data = accel_data.rename(columns = {"Final Best Time": "Best Acceleration Time"})
#accel_data = accel_data.drop(columns = ["Place", "Car Num", "Run 1 Time", "Run 1 Adj Time", "Run 2 Time", "Run 2 Adj Time", "Run 3 Time", "Run 3 Adj Time", "Run 4 Time", "Run 4 Adj Time"])
merged_data = pd.merge(merged_data, accel_data, on= 'Team', how = 'outer')

autocross_data = pd.read_csv("./fsae_data/2025/fsae_autocross_results.csv", index_col=False)
autocross_data = autocross_data[["Team", "Best Time"]]
autocross_data = autocross_data.rename(columns = {"Best Time": "Best Autocross Time"})
#autocross_data = autocross_data.drop(columns = ["Place", "Car Num", "Penalty","R1 Time","R1 Cones","R1 Off Course","R1 Adj Time","R2 Time","R2 Cones","R2 Off Course","R2 Adj Time","R3 Time","R3 Cones","R3 Off Course","R3 Adj Time","R4 Time","R4 Cones","R4 Off Course","R4 Adj Time"])
merged_data = pd.merge(merged_data, autocross_data, on= 'Team', how = 'outer')

endurance_data = pd.read_csv("./fsae_data/2025/fsae_endurance_results.csv", index_col=False)
#endurance_data = endurance_data.drop(columns = ["Place", "Car Num", "Cones", "Endurance Score"])
endurance_data = endurance_data[["Team", "Time", "Other Penalty", "Adjusted Time", "Time Score", "Laps", "Laps Score"]]
endurance_data = endurance_data.rename(columns = {"Time": "Endurance Time", "Other Penalty": "Endurance Penalty", "Adjusted Time": "Adjusted Endurance Time", "Time Score": "Endurance Time Score", "Laps": "Endurance Laps", "Laps Score": "Endurance Laps Score"})
merged_data = pd.merge(merged_data, endurance_data, on= 'Team', how = 'outer')

skidpad_data = pd.read_csv("./fsae_data/2025/fsae_skidpad_results.csv", index_col=False)
skidpad_data = skidpad_data[["Team", "Best Time"]]
skidpad_data = skidpad_data.rename(columns = {"Best Time": "Best Skidpad Time"})
merged_data = pd.merge(merged_data, skidpad_data, on= 'Team', how = 'outer')


team_data = pd.read_csv("./fsae_data/2025/fsae_team_info.csv", index_col=False)
team_data = team_data[["Team", "Engine Cylinders", "Engine Displacement (cc)", "Weight (kg)"]]
merged_data = pd.merge(merged_data, team_data, on= 'Team', how = 'outer')

merged_data["Team"] = merged_data["Team"] + "_2025"
merged_data_2025 = merged_data
#print(merged_data)

# %%
# data load
base_data = pd.read_csv("./fsae_data/2024/fsae_2024_overall_results_clean.csv")

cost_data = pd.read_csv("./fsae_data/2024/fsae_2024_cost_event_results_clean.csv")
# cost_data = cost_data.drop(columns=["Place", "Car Num", "Penalty", "Score", "Penalty"])
cost_data = cost_data[["Team", "Adjusted Cost"]]
merged_data = pd.merge(base_data, cost_data, on = 'Team', how = "outer")

efficiency_data = pd.read_csv("./fsae_data/2024/fsae_2024_efficiency_results_clean.csv")
#efficiency_data = efficiency_data.drop(columns = ["Place", "Car Num", "Fuel Efficiency Score"])
efficiency_data = efficiency_data[["Team", "Average Adjusted Laptime", "Fuel Efficiency Factor"]]
merged_data = pd.merge(merged_data, efficiency_data, on= 'Team', how = 'outer')

accel_data = pd.read_csv("./fsae_data/2024/fsae_2024_acceleration_results_clean.csv", index_col=False)
accel_data = accel_data[["Team", "Best Time"]]
accel_data = accel_data.rename(columns = {"Best Time": "Best Acceleration Time"})
#accel_data = accel_data.drop(columns = ["Place", "Car Num", "Run 1 Time", "Run 1 Adj Time", "Run 2 Time", "Run 2 Adj Time", "Run 3 Time", "Run 3 Adj Time", "Run 4 Time", "Run 4 Adj Time"])
merged_data = pd.merge(merged_data, accel_data, on= 'Team', how = 'outer')

autocross_data = pd.read_csv("./fsae_data/2024/fsae_2024_autocross_results_clean.csv", index_col=False)
autocross_data = autocross_data[["Team", "Best Time"]]
autocross_data = autocross_data.rename(columns = {"Best Time": "Best Autocross Time"})
#autocross_data = autocross_data.drop(columns = ["Place", "Car Num", "Penalty","R1 Time","R1 Cones","R1 Off Course","R1 Adj Time","R2 Time","R2 Cones","R2 Off Course","R2 Adj Time","R3 Time","R3 Cones","R3 Off Course","R3 Adj Time","R4 Time","R4 Cones","R4 Off Course","R4 Adj Time"])
merged_data = pd.merge(merged_data, autocross_data, on= 'Team', how = 'outer')

endurance_data = pd.read_csv("./fsae_data/2024/fsae_2024_endurance_results_clean.csv", index_col=False)
#endurance_data = endurance_data.drop(columns = ["Place", "Car Num", "Cones", "Endurance Score"])
endurance_data = endurance_data[["Team", "Time", "Other Penalty", "Adjusted Time", "Time Score", "Laps", "Laps Score"]]
endurance_data = endurance_data.rename(columns = {"Time": "Endurance Time", "Other Penalty": "Endurance Penalty", "Adjusted Time": "Adjusted Endurance Time", "Laps": "Endurance Laps"})
merged_data = pd.merge(merged_data, endurance_data, on= 'Team', how = 'outer')

skidpad_data = pd.read_csv("./fsae_data/2024/fsae_2024_skidpad_results_clean.csv", index_col=False)
skidpad_data = skidpad_data[["Team", "Best Time"]]
skidpad_data = skidpad_data.rename(columns = {"Best Time": "Best Skidpad Time"})
merged_data = pd.merge(merged_data, skidpad_data, on= 'Team', how = 'outer')


team_data = pd.read_csv("./fsae_data/2024/fsae_2024_team_information_clean.csv", index_col=False)
team_data = team_data[["Team", "Engine Cylinders", "Engine Displacement (cc)", "Weight (kg)"]]
merged_data = pd.merge(merged_data, team_data, on= 'Team', how = 'outer')

merged_data["Team"] = merged_data["Team"] + "_2024"
merged_data_2024 = merged_data
#print(merged_data)

# %%
# data load
base_data = pd.read_csv("./fsae_data/2023/fsae_2023_overall_results_clean.csv")
cost_data = pd.read_csv("./fsae_data/2023/fsae_2023_cost_event_results_clean.csv")
# cost_data = cost_data.drop(columns=["Place", "Car Num", "Penalty", "Score", "Penalty"])
cost_data = cost_data[["Team", "Adjusted Cost"]]
merged_data = pd.merge(base_data, cost_data, on = 'Team', how = "outer")

efficiency_data = pd.read_csv("./fsae_data/2023/fsae_2023_efficiency_results_clean.csv")
#efficiency_data = efficiency_data.drop(columns = ["Place", "Car Num", "Fuel Efficiency Score"])
efficiency_data = efficiency_data[["Team", "Average Adjusted Laptime", "Fuel Efficiency Factor"]]
merged_data = pd.merge(merged_data, efficiency_data, on= 'Team', how = 'outer')

accel_data = pd.read_csv("./fsae_data/2023/fsae_2023_acceleration_results_clean.csv", index_col=False)
accel_data = accel_data[["Team", "Best Time"]]
accel_data = accel_data.rename(columns = {"Best Time": "Best Acceleration Time"})
#accel_data = accel_data.drop(columns = ["Place", "Car Num", "Run 1 Time", "Run 1 Adj Time", "Run 2 Time", "Run 2 Adj Time", "Run 3 Time", "Run 3 Adj Time", "Run 4 Time", "Run 4 Adj Time"])
merged_data = pd.merge(merged_data, accel_data, on= 'Team', how = 'outer')

autocross_data = pd.read_csv("./fsae_data/2023/fsae_2023_autocross_results_clean.csv", index_col=False)
autocross_data = autocross_data[["Team", "Best Time"]]
autocross_data = autocross_data.rename(columns = {"Best Time": "Best Autocross Time"})
#autocross_data = autocross_data.drop(columns = ["Place", "Car Num", "Penalty","R1 Time","R1 Cones","R1 Off Course","R1 Adj Time","R2 Time","R2 Cones","R2 Off Course","R2 Adj Time","R3 Time","R3 Cones","R3 Off Course","R3 Adj Time","R4 Time","R4 Cones","R4 Off Course","R4 Adj Time"])
merged_data = pd.merge(merged_data, autocross_data, on= 'Team', how = 'outer')

endurance_data = pd.read_csv("./fsae_data/2023/fsae_2023_endurance_results_clean.csv", index_col=False)
#endurance_data = endurance_data.drop(columns = ["Place", "Car Num", "Cones", "Endurance Score"])
endurance_data = endurance_data[["Team", "Time", "Adjusted Time", "Laps"]]
endurance_data = endurance_data.rename(columns = {"Time": "Endurance Time", "Adjusted Time": "Adjusted Endurance Time", "Time Score": "Endurance Time Score", "Laps": "Endurance Laps", "Laps Score": "Endurance Laps Score"})
merged_data = pd.merge(merged_data, endurance_data, on= 'Team', how = 'outer')

skidpad_data = pd.read_csv("./fsae_data/2023/fsae_2023_skidpad_results_clean.csv", index_col=False)
skidpad_data = skidpad_data[["Team", "Best Time"]]
skidpad_data = skidpad_data.rename(columns = {"Best Time": "Best Skidpad Time"})
merged_data = pd.merge(merged_data, skidpad_data, on= 'Team', how = 'outer')


team_data = pd.read_csv("./fsae_data/2023/fsae_2023_team_information_results_clean.csv", index_col=False)
team_data = team_data[["Team", "Engine Cylinders", "Engine Displacement (cc)", "Weight (kg)"]]
merged_data = pd.merge(merged_data, team_data, on= 'Team', how = 'outer')

merged_data["Team"] = merged_data["Team"] + "_2023"
merged_data_2023 = merged_data

# %%
# data load
base_data = pd.read_csv("./fsae_data/2019/fsae_2019_overall_result_clean.csv")
cost_data = pd.read_csv("./fsae_data/2019/fsae_2019_cost_event_result_clean.csv")
# cost_data = cost_data.drop(columns=["Place", "Car Num", "Penalty", "Score", "Penalty"])
cost_data = cost_data[["Team", "Adjusted Cost"]]
merged_data = pd.merge(base_data, cost_data, on = 'Team', how = "outer")

efficiency_data = pd.read_csv("./fsae_data/2019/fsae_2019_fuel_efficiency_result_clean.csv")
#efficiency_data = efficiency_data.drop(columns = ["Place", "Car Num", "Fuel Efficiency Score"])
efficiency_data = efficiency_data[["Team", "Average Adjusted Laptime", "Fuel Efficiency Factor"]]
merged_data = pd.merge(merged_data, efficiency_data, on= 'Team', how = 'outer')

accel_data = pd.read_csv("./fsae_data/2019/fsae_2019_acceleration_result_clean.csv", encoding='ISO-8859-1', index_col=False)
accel_data = accel_data[["Team", "Best Time"]]
accel_data = accel_data.rename(columns = {"Best Time": "Best Acceleration Time"})
#accel_data = accel_data.drop(columns = ["Place", "Car Num", "Run 1 Time", "Run 1 Adj Time", "Run 2 Time", "Run 2 Adj Time", "Run 3 Time", "Run 3 Adj Time", "Run 4 Time", "Run 4 Adj Time"])
merged_data = pd.merge(merged_data, accel_data, on= 'Team', how = 'outer')

autocross_data = pd.read_csv("./fsae_data/2019/fsae_2019_autocross_result_clean.csv", encoding='ISO-8859-1',index_col=False)
autocross_data = autocross_data[["Team", "Best Time"]]
autocross_data = autocross_data.rename(columns = {"Best Time": "Best Autocross Time"})
#autocross_data = autocross_data.drop(columns = ["Place", "Car Num", "Penalty","R1 Time","R1 Cones","R1 Off Course","R1 Adj Time","R2 Time","R2 Cones","R2 Off Course","R2 Adj Time","R3 Time","R3 Cones","R3 Off Course","R3 Adj Time","R4 Time","R4 Cones","R4 Off Course","R4 Adj Time"])
merged_data = pd.merge(merged_data, autocross_data, on= 'Team', how = 'outer')

endurance_data = pd.read_csv("./fsae_data/2019/fsae_2019_endurance_result_clean.csv", index_col=False)
#endurance_data = endurance_data.drop(columns = ["Place", "Car Num", "Cones", "Endurance Score"])
endurance_data = endurance_data[["Team", "Time", "Adjusted Time", "Laps"]]
endurance_data = endurance_data.rename(columns = {"Time": "Endurance Time", "Adjusted Time": "Adjusted Endurance Time", "Time Score": "Endurance Time Score", "Laps": "Endurance Laps", "Laps Score": "Endurance Laps Score"})
merged_data = pd.merge(merged_data, endurance_data, on= 'Team', how = 'outer')

skidpad_data = pd.read_csv("./fsae_data/2019/fsae_2019_skidpad_result_clean.csv", encoding='ISO-8859-1', index_col=False)
skidpad_data = skidpad_data[["Team", "Best Time"]]
skidpad_data = skidpad_data.rename(columns = {"Best Time": "Best Skidpad Time"})
merged_data = pd.merge(merged_data, skidpad_data, on= 'Team', how = 'outer')


team_data = pd.read_csv("./fsae_data/2019/fsae_2019_team_information_result_clean.csv", index_col=False)
team_data = team_data[["Team", "Engine Cylinders", "Engine Displacement (cc)", "Weight (kg)"]]
merged_data = pd.merge(merged_data, team_data, on= 'Team', how = 'outer')

merged_data["Team"] = merged_data["Team"] + "_2019"
merged_data_2019 = merged_data

# %%
# data load
base_data = pd.read_csv("./fsae_data/2018/fsae_2018_overall_result_clean.csv")
cost_data = pd.read_csv("./fsae_data/2018/fsae_2018_cost_event_result_clean.csv")
# cost_data = cost_data.drop(columns=["Place", "Car Num", "Penalty", "Score", "Penalty"])
cost_data = cost_data[["Team", "Adjusted Cost"]]
merged_data = pd.merge(base_data, cost_data, on = 'Team', how = "outer")

efficiency_data = pd.read_csv("./fsae_data/2018/fsae_2018_fuel_efficiency_result_clean.csv")
#efficiency_data = efficiency_data.drop(columns = ["Place", "Car Num", "Fuel Efficiency Score"])
efficiency_data = efficiency_data[["Team", "Average Adjusted Laptime", "Fuel Efficiency Factor"]]
merged_data = pd.merge(merged_data, efficiency_data, on= 'Team', how = 'outer')

accel_data = pd.read_csv("./fsae_data/2018/fsae_2018_acceleration_result_clean.csv", encoding='ISO-8859-1', index_col=False)
accel_data = accel_data[["Team", "Best Time"]]
accel_data = accel_data.rename(columns = {"Best Time": "Best Acceleration Time"})
#accel_data = accel_data.drop(columns = ["Place", "Car Num", "Run 1 Time", "Run 1 Adj Time", "Run 2 Time", "Run 2 Adj Time", "Run 3 Time", "Run 3 Adj Time", "Run 4 Time", "Run 4 Adj Time"])
merged_data = pd.merge(merged_data, accel_data, on= 'Team', how = 'outer')

autocross_data = pd.read_csv("./fsae_data/2018/fsae_2018_autocross_result_clean.csv", encoding='ISO-8859-1',index_col=False)
autocross_data = autocross_data[["Team", "Best Time"]]
autocross_data = autocross_data.rename(columns = {"Best Time": "Best Autocross Time"})
#autocross_data = autocross_data.drop(columns = ["Place", "Car Num", "Penalty","R1 Time","R1 Cones","R1 Off Course","R1 Adj Time","R2 Time","R2 Cones","R2 Off Course","R2 Adj Time","R3 Time","R3 Cones","R3 Off Course","R3 Adj Time","R4 Time","R4 Cones","R4 Off Course","R4 Adj Time"])
merged_data = pd.merge(merged_data, autocross_data, on= 'Team', how = 'outer')

endurance_data = pd.read_csv("./fsae_data/2018/fsae_2018_endurance_result_clean.csv", index_col=False)
#endurance_data = endurance_data.drop(columns = ["Place", "Car Num", "Cones", "Endurance Score"])
endurance_data = endurance_data[["Team", "Time", "Adjusted Time", "Laps"]]
endurance_data = endurance_data.rename(columns = {"Time": "Endurance Time", "Adjusted Time": "Adjusted Endurance Time", "Time Score": "Endurance Time Score", "Laps": "Endurance Laps", "Laps Score": "Endurance Laps Score"})
merged_data = pd.merge(merged_data, endurance_data, on= 'Team', how = 'outer')

skidpad_data = pd.read_csv("./fsae_data/2018/fsae_2018_skidpad_result_clean.csv", encoding='ISO-8859-1', index_col=False)
skidpad_data = skidpad_data[["Team", "Best Time"]]
skidpad_data = skidpad_data.rename(columns = {"Best Time": "Best Skidpad Time"})
merged_data = pd.merge(merged_data, skidpad_data, on= 'Team', how = 'outer')


team_data = pd.read_csv("./fsae_data/2018/fsae_2018_team_information_result_clean.csv", index_col=False)
team_data = team_data[["Team", "Engine Cylinders", "Engine Displacement (cc)", "Weight (kg)"]]
merged_data = pd.merge(merged_data, team_data, on= 'Team', how = 'outer')

merged_data["Team"] = merged_data["Team"] + "_2018"
merged_data_2018 = merged_data

# %%
merged_data = ultra_data = pd.concat([merged_data_2025, merged_data_2024, merged_data_2023, merged_data_2019, merged_data_2018], axis = 0, ignore_index=True)
merged_data = merged_data.dropna(subset=["Team", "Car Num"])
merged_data["Place"] = merged_data["Place"].fillna("Unranked")
labels = ["Quartile 1", "Quartile 2", "Quartile 3", "Quartile 4"]
print(merged_data)
# Out:
#         Place  Car Num                                           Team  \
# 0    Unranked    135.0                        Alabama A & M Univ_2025
# 1          75     49.0                Arizona State Univ - Tempe_2025
# 2          18     30.0                                Brown Univ_2025
# 3          33    148.0                                  CEFET-MG_2025
# 4          39     89.0       California State Poly Univ - Pomona_2025
# 5       106 T    129.0             California State Univ - Chico_2025
# 6          82     67.0         California State Univ - Fullerton_2025
# 7          11     84.0        California State Univ - Northridge_2025
# 8    Unranked    144.0                            Calvin College_2025
# 9          80     55.0                             Carleton Univ_2025
# 10         62     50.0                       Clarkson University_2025
# 11         46     58.0                              Clemson Univ_2025
# 12         79     99.0                  Colorado Mesa University_2025
# 13         34     23.0                  Colorado School of Mines_2025
# 14         59     44.0                 Colorado State University_2025
# 15   Unranked     63.0                               Drexel Univ_2025
# 16         16     34.0                                 Duke Univ_2025
# 17         20     32.0    Embry-Riddle Aero Univ - Daytona Beach_2025
# 18         66     79.0                     Florida Atlantic Univ_2025
# 19         76     57.0                Florida International Univ_2025
# 20          3     38.0           Georgia Institute of Technology_2025
# 21        101    113.0                   Grand Canyon University_2025
# 22         63     64.0                   Grand Valley State Univ_2025
# 23        104    126.0                 ITESM - Campus Cuernavaca_2025
# 24         21      7.0              Instituto Maua de Tecnologia_2025
# 25   Unranked     25.0        Instituto Tecnologico de Chihuahua_2025
# 26        103    134.0  Instituto Tecnologico de Estudios Superi_2025
# 28          4     10.0                         Kansas State Univ_2025
# 29         56    119.0                 Kennesaw State University_2025
# 30         88     27.0                            Kettering Univ_2025
# 31         89     33.0                             Lakehead Univ_2025
# 32         65     69.0               Lawrence Technological Univ_2025
# 33         28     31.0                               Lehigh Univ_2025
# 34         35    118.0                              Liberty Univ_2025
# 35         45     93.0                        Michigan Tech Univ_2025
# 36         30     45.0      Minnesota State University - Mankato_2025
# 37         53     75.0                    Mississippi State Univ_2025
# 38         90     78.0                 Missouri State University_2025
# 39         23     98.0   Missouri University of Science and Tech_2025
# 40         98     40.0              Montana State Univ - Bozeman_2025
# 41   Unranked    133.0                       New York University_2025
# 42         43    128.0       North Carolina State Univ - Raleigh_2025
# 43        105    116.0                   North Dakota State Univ_2025
# 44         94     72.0                     Northern Arizona Univ_2025
# 45        100    105.0                    Northern Illinois Univ_2025
# 46         13    138.0                        Oakland University_2025
# 47         51    117.0                       Oklahoma State Univ_2025
# 48   Unranked     37.0                         Old Dominion Univ_2025
# 49         95     47.0                       Oregon Inst of Tech_2025
# 50         86     41.0       Pellissippi State Community College_2025
# 51   Unranked     83.0              Penn State Univ - Harrisburg_2025
# 52         84     95.0                   Purdue Univ - Northwest_2025
# 53          6      8.0                 Purdue Univ - W Lafayette_2025
# 54         27     52.0                     Sacramento State Univ_2025
# 55         64     36.0                 Saginaw Valley State Univ_2025
# 56         37     80.0       South Dakota School of Mines & Tech_2025
# 57         78     82.0                   South Dakota State Univ_2025
# 58         54    125.0       Southern Illinois Univ - Carbondale_2025
# 59      106 T    114.0      Southern Illinois Univ - Edwardville_2025
# 60         96    141.0                       St Cloud State Univ_2025
# 61   Unranked    136.0                             Syracuse Univ_2025
# 62         50    108.0                               Temple Univ_2025
# 63         61     54.0                       Tennessee Tech Univ_2025
# 64          2      5.0        Texas A & M Univ - College Station_2025
# 65         99    122.0                              Trinity Univ_2025
# 66         97    109.0                         UP Aguascalientes_2025
# 67         69     70.0                          US Naval Academy_2025
# 69          8     48.0                Univ of Alabama Tuscaloosa_2025
# 70         81    100.0                           Univ of Arizona_2025
# 71         57     24.0                  Univ of British Columbia_2025
# 72         17      3.0                  Univ of Calif - Berkeley_2025
# 73         74     35.0                    Univ of Calif - Irvine_2025
# 74         77     39.0                   Univ of Central Florida_2025
# 75         44     60.0                        Univ of Cincinnati_2025
# 77   Unranked    121.0       Univ of Colorado - Colorado Springs_2025
# 78         31    103.0                  Univ of Colorado Boulder_2025
# 79         29      4.0                       Univ of Connecticut_2025
# 80         70     86.0                          Univ of Delaware_2025
# 81         38     59.0                           Univ of Georgia_2025
# 82         49    107.0                          Univ of Hartford_2025
# 84         87     53.0                   Univ of Houston Houston_2025
# 85         47    115.0                Univ of Illinois - Chicago_2025
# 86         67     88.0                          Univ of Kentucky_2025
# 87        102    142.0                             Univ of Maine_2025
# 88         40    101.0                          Univ of Manitoba_2025
# 89         25     56.0           Univ of Maryland - College Park_2025
# 90         93    123.0            Univ of Massachusetts - Lowell_2025
# 91         26     92.0               Univ of Michigan - Dearborn_2025
# 92   Unranked    127.0                  Univ of Minnesota-Duluth_2025
# 93         22     22.0                          Univ of Missouri_2025
# 94         14     43.0                Univ of Nebraska - Lincoln_2025
# 96         10      2.0          Univ of North Carolina Charlotte_2025
# 97         41     77.0                     Univ of North Florida_2025
# 98         72     46.0                          Univ of Oklahoma_2025
# 99         83     87.0                            Univ of Ottawa_2025
# 100        71    120.0                      Univ of Saskatchewan_2025
# 101        52     71.0                     Univ of South Florida_2025
# 102        36    131.0               Univ of Southern California_2025
# 103         9     81.0                 Univ of Texas - Arlington_2025
# 104        48    104.0                    Univ of Texas - Austin_2025
# 105  Unranked     26.0                    Univ of Texas - Dallas_2025
# 106        42     96.0                            Univ of Toledo_2025
# 650      72.0    126.0                Univ of Nebraska - Lincoln_2018
# 651     110.0     83.0                     Univ of New Hampshire_2018
# 652      65.0     79.0        Univ of North Carolina - Charlotte_2018
# 653      67.0     91.0                     Univ of North Florida_2018
# 654     100.0     35.0           Univ of Pittsburgh - Pittsburgh_2018
# 655      25.0     69.0                      Univ of Saskatchewan_2018
# 656      57.0    135.0                     Univ of South Florida_2018
# 657      52.0     39.0                            Univ of Toledo_2018
# 658      71.0     26.0                           Univ of Toronto_2018
# 659      48.0    115.0                          Univ of Victoria_2018
# 660      22.0    122.0                          Univ of Waterloo_2018
# 661       8.0     10.0               Univ of Wisconsin - Madison_2018
# 662     105.0    110.0        Universidad Autonoma Estado Mexico_2018
# 664     111.0    132.0   Universidad Nacional Autónoma de México_2018
# 665       3.0     75.0       Universidad Politecnica de Valencia_2018
# 666      42.0     46.0                 Universidad Simon Bolivar_2018
# 667       1.0      1.0                     Universitat Stuttgart_2018
# 668      86.0    103.0           Universite Du Quebec-Chicoutimi_2018
# 669      43.0     76.0                  Universite de Sherbrooke_2018
# 670      17.0     99.0                            Villanova Univ_2018
# 671      60.0     52.0                             Virginia Tech_2018
# 672      97.0     87.0                     Washington State Univ_2018
# 673      61.0     40.0                Washington Univ - St Louis_2018
# 674      37.0     72.0                          Wayne State Univ_2018
# 675      77.0    112.0                     Western Michigan Univ_2018
# 676      54.0     55.0                        Western University_2018
# 677      41.0     84.0                Worcester Polytechnic Inst_2018
# 678      80.0     29.0              York College of Pennsylvania_2018
#
#      Penalty  Cost Score  Presentation Score  Design Score  \
# 0        NaN        18.5                 NaN           NaN
# 1        NaN        78.1                51.5          90.0
# 2        NaN        87.2                59.7         100.0
# 3        NaN        82.5                67.7         139.0
# 4        NaN        72.0                18.2         100.0
# 5        NaN       -50.0                14.3           NaN
# 6        NaN        47.7                61.0          60.0
# 7        NaN        85.9                38.9         100.0
# 8        NaN        13.3                 NaN           NaN
# 9        NaN        72.3                38.0          80.0
# 10       NaN        57.8                18.5          60.0
# 11       NaN        54.6                54.0          80.0
# 12       NaN        58.1                 5.0          40.0
# 13       NaN        62.5                38.2          80.0
# 14       NaN        54.7                19.1          60.0
# 15       NaN        17.1                 NaN           NaN
# 16       NaN        75.8                71.3          80.0
# 17       NaN        31.9                68.9          80.0
# 18       NaN        54.1                18.8          60.0
# 19       NaN        62.3                16.5          35.0
# 20       NaN        83.1                43.8         100.0
# 21       NaN        18.9                16.1          30.0
# 22       NaN        65.5                19.1          60.0
# 23       NaN        15.5                10.0          10.0
# 24       NaN        88.8                54.3         129.0
# 25       NaN         NaN                 NaN           2.5
# 26       NaN        14.0                 5.0          20.0
# 28       NaN        66.8                70.6         100.0
# 29       NaN        93.8                15.9          80.0
# 30       NaN        63.1                11.9          60.0
# 31       NaN        47.0                45.9          40.0
# 32       NaN        62.3                19.6          40.0
# 33       NaN        67.5                17.6          60.0
# 34       NaN        83.2                14.1          60.0
# 35       NaN        76.4                14.2         100.0
# 36       NaN        78.9                43.1          80.0
# 37       NaN        77.4                66.9          75.0
# 38       NaN        56.3                32.8          40.0
# 39       NaN        70.5                67.8         100.0
# 40       NaN        42.2                20.0          20.0
# 41       NaN        20.0                 NaN           NaN
# 42       NaN        70.7                37.1         100.0
# 43       NaN       -50.0                12.0          20.0
# 44       NaN        39.3                29.1          40.0
# 45       NaN        34.7                13.3          20.0
# 46       NaN        68.1                60.0          80.0
# 47       NaN       -11.0                51.8          60.0
# 48       NaN        18.2                 NaN           NaN
# 49       NaN        35.1                 NaN          60.0
# 50       NaN        46.6                56.3          40.0
# 51       NaN        20.0                 NaN           NaN
# 52       NaN        61.2                34.0          60.0
# 53       NaN        66.8                41.8         150.0
# 54       NaN        67.0                15.9          80.0
# 55       NaN        62.9                 6.6          45.0
# 56       NaN        46.3                25.0          60.0
# 57       NaN        50.6                14.8          40.0
# 58       NaN        24.9                25.2          35.0
# 59       NaN       -50.0                17.6           NaN
# 60       NaN        26.8                16.1          40.0
# 61       NaN        15.4                 NaN           NaN
# 62       NaN        68.0                58.1          80.0
# 63       NaN        71.0                18.9          60.0
# 64       NaN        78.5                66.4         113.0
# 65     -20.0        31.9                48.6          10.0
# 66       NaN        56.6                10.9          15.0
# 67       NaN        27.3                14.2          60.0
# 69       NaN        59.6                59.4         116.0
# 70       NaN        59.1                51.0          40.0
# 71       NaN        73.5                19.1         100.0
# 72       NaN        80.3                59.5         100.0
# 73       NaN        40.9                18.5          60.0
# 74       NaN        53.8                14.3          80.0
# 75       NaN        50.5                34.7          80.0
# 77       NaN        20.0                 NaN           NaN
# 78       NaN        67.1                42.0          80.0
# 79       NaN        66.8                69.0         100.0
# 80       NaN        38.1                17.0          40.0
# 81       NaN        62.5                64.4          80.0
# 82       NaN        40.0                18.9          60.0
# 84       NaN        58.3                41.2          40.0
# 85       NaN        81.2                55.6          40.0
# 86       NaN        55.0                19.6          60.0
# 87       NaN        43.9                 NaN          20.0
# 88       NaN        68.7                50.2          75.0
# 89       NaN        81.5                67.6         100.0
# 90       NaN        71.5                28.1          10.0
# 91       NaN        72.4                19.7          80.0
# 92       NaN        20.0                 NaN           NaN
# 93       NaN        63.2                50.4          80.0
# 94       NaN        64.6                55.0         100.0
# 96       NaN        79.8                75.0         111.0
# 97       NaN        61.0                51.3          75.0
# 98       NaN        57.9                17.7          60.0
# 99       NaN        56.4                40.7          60.0
# 100      NaN        67.6                44.1          35.0
# 101      NaN        52.0                14.2          80.0
# 102      NaN        57.7                29.7         121.0
# 103      NaN        84.4                41.3         105.0
# 104      NaN        88.6                52.4         100.0
# 105      NaN        51.3                 NaN           NaN
# 106      NaN        44.0                17.7          40.0
# 107      NaN        71.2                43.9         100.0
# 108      NaN        79.1                48.3         135.0
# 109      NaN        52.8                46.5          80.0
# 110      NaN        19.6                 NaN           NaN
# 111      NaN        15.0                 NaN           NaN
# 112      NaN        80.0                16.6          40.0
# 113      NaN        74.7                42.6          10.0
# 114      NaN        83.2                50.4         133.0
# 115      NaN        66.7                46.4         100.0
# 116      NaN        20.0                 NaN           NaN
# 117      NaN        81.3                59.3          80.0
# 118      NaN        69.7                58.2         100.0
# 119      NaN        52.5                54.3          55.0
# 120      NaN        63.7                15.9          80.0
# 121      NaN        71.3                53.0          80.0
# 122      NaN        57.0                40.1          60.0
# 123      NaN        74.4                11.9          60.0
# 124      NaN        52.2                11.6          60.0
# 125      NaN        85.4                35.4          80.0
# 126      NaN        49.1                65.6         132.0
# 127      NaN         NaN                 NaN           NaN
# 128      NaN        77.3                27.6         100.0
# 129      NaN        55.7                33.2          30.0
# 130      NaN        79.0                56.7          80.0
# 131      NaN        73.3                33.5          40.0
# 132      NaN        80.7                37.4         100.0
# 133      NaN        62.0                56.0         100.0
# 134      NaN        59.1                49.1          30.0
# 135      NaN        38.9                27.5          80.0
# 136      NaN        69.8                49.8         119.0
# 137      NaN        75.3                57.9          80.0
# 138      NaN        43.5                31.4          60.0
# 139      NaN        75.3                50.4         100.0
# 140      NaN        50.0                27.6          50.0
# 141      NaN        39.4                45.8          80.0
# 142      NaN        62.9                28.7          45.0
# 143    -10.0        66.6                29.9          40.0
# 144      NaN        76.1                68.0          80.0
# 145      NaN        59.7                68.5          40.0
# 146      NaN        39.2                45.1          55.0
# 147      NaN        68.8                41.0          75.0
# 148      NaN        78.6                75.0         100.0
# 149      NaN        57.3                43.6          75.0
# 150      NaN         NaN                23.5           NaN
# 151      NaN        83.7                35.1         150.0
# 152      NaN         NaN                15.5          10.0
# 153      NaN         NaN                53.5           NaN
# 154      NaN        64.5                60.0         100.0
# 155      NaN        87.0                72.8          80.0
# 156      NaN        53.2                28.1          80.0
# 157      NaN         NaN                 NaN           NaN
# 158      NaN        48.1                29.8          40.0
# 159      NaN        77.1                36.1          60.0
# ...
# 158        247.2       40.4        25.0
# 159        175.1          -        25.0
# 160        213.6        NaN         NaN
# 161        236.8        NaN         NaN
# 162        210.0      106.4        25.0
# 163        189.6      102.4        25.0
# 164          NaN        NaN         NaN
# 165        216.8          -         6.0
# 166        192.3          -        12.0
# 167          NaN        NaN         NaN
# 168        244.9          -        25.0
# 169        226.8        NaN         NaN
# 170        231.3      151.4        25.0
# 171        238.6       12.5        25.0
# 172        220.4          -         6.0
# 173        204.6        NaN         NaN
# 174        230.4        NaN         NaN
# 175        200.5        NaN         NaN
# 176        218.2      160.9        25.0
# 177        174.6          -         0.0
# 178        210.9       82.9        25.0
# 179        201.4          -         4.0
# 180        221.4        NaN         NaN
# 181        201.8          -        12.0
# 182        235.0          -         6.0
# 183        237.2        NaN         NaN
# 184        270.3          -        25.0
# 185        187.8      140.4        25.0
# 186        170.6        NaN         NaN
# 187        200.5      216.2        25.0
# 188        187.8        NaN         NaN
# 189        201.4        250        25.0
# 190          NaN        NaN         NaN
# 191        201.4       11.5        25.0
# 192        181.4          -         0.0
# 193        219.5      140.5        25.0
# 194          NaN        NaN         NaN
# 195        202.8          -         0.0
# 196        168.3      237.3        25.0
# 197          NaN        NaN         NaN
# 198        194.6        NaN         NaN
# 199        204.6      122.1        25.0
# 200        213.6          -        12.0
# 201        223.6      201.7        25.0
# 202        233.1          -        25.0
# 203        230.9          -         2.0
# 204        188.2          -        12.0
# 205          NaN        NaN         NaN
# 206        215.5       56.6        25.0
# 207        213.6          -        25.0
# 208        218.6        NaN         NaN
# 209        223.6        NaN         NaN
# 210          NaN        NaN         NaN
# 211        192.8        NaN         NaN
# 212        214.5       89.9        25.0
# 213        235.9        NaN         NaN
# 214        232.7      169.3        25.0
# 215        208.7       57.2        25.0
# 216        169.2      231.4        25.0
# 217        228.6          -        20.0
# 218        231.8          -        14.0
# 219        205.0          -        25.0
# 220        199.6          -        25.0
# 221        240.4          -         8.0
# 222        219.5      106.1        25.0
# 223        220.4          -        16.0
# 224        217.3          -        12.0
# 225        249.5       86.7        25.0
# 226        233.6        NaN         NaN
# 227        232.2       85.4        25.0
# 228        211.8          -        16.0
# 229        215.0          -        16.0
# 230        245.4      111.9        25.0
# 231          NaN          -        12.0
# 232        246.3        NaN         NaN
# 233        294.8        NaN         NaN
# 234        269.4        NaN         NaN
# 235        200.5      108.6        25.0
# 236        162.8      102.5        25.0
# 237        206.8      185.5        25.0
# 238        176.4          -        14.0
# 239        258.1        NaN         NaN
# 240        213.2          -        25.0
# 241        209.6        NaN         NaN
# 242        198.2        NaN         NaN
# 243          NaN        NaN         NaN
# 244        253.1          -        25.0
# 248        291.2        NaN         NaN
# 250        262.6        NaN         NaN
# 251        208.7        NaN         NaN
# 258        213.2        NaN         NaN
# 264        249.0        NaN         NaN
# 269          NaN        NaN         NaN
# 272          NaN        NaN         NaN
# 276        174.6        NaN         NaN
# 277        304.4        NaN         NaN
# 279        166.5        NaN         NaN
# 280        240.4        NaN         NaN
# 285        192.8        NaN         NaN
# 292        245.4        NaN         NaN
# 293        203.2        NaN         NaN
# 295          NaN        NaN         NaN
# 297        221.8        NaN         NaN
# 299          NaN        NaN         NaN
# 301        213.6        NaN         NaN
# 302          NaN        NaN         NaN
# 304        186.4        NaN         NaN
# 306        181.4        NaN         NaN
# 308        284.4        NaN         NaN
# 310          NaN        NaN         NaN
# 311        207.7        NaN         NaN
# 312          NaN        NaN         NaN
# 313        208.2        NaN         NaN
# 317        241.8        NaN         NaN
# 320        207.7        NaN         NaN
# 324        237.7        NaN         NaN
# 325        209.1        NaN         NaN
# 330        194.6        NaN         NaN
# 332        230.0        NaN         NaN
# 333        190.1        NaN         NaN
# 334        248.1        NaN         NaN
# 337        222.3        NaN         NaN
# 341        213.6        NaN         NaN
# 346        235.9        NaN         NaN
# 352        212.3        NaN         NaN
# 357        244.9        NaN         NaN
# 359        277.1        NaN         NaN
# 360        192.3        NaN         NaN
# 362        262.2        NaN         NaN
# 363        205.0        NaN         NaN
# 364          NaN        NaN         NaN
# 366        226.3        NaN         NaN
# 368        254.9        NaN         NaN
# 372        193.7        NaN         NaN
# 373          NaN        NaN         NaN
# 374          NaN        NaN         NaN
# 375        299.8        NaN         NaN
# 376        231.8        NaN         NaN
# 377        198.7        NaN         NaN
# 378        209.1        NaN         NaN
# 379          NaN        NaN         NaN
# 380          NaN        NaN         NaN
# 381        162.4        NaN         NaN
# 382          NaN        NaN         NaN
# 383        219.1        NaN         NaN
# 384        221.8        NaN         NaN
# 385        181.9        NaN         NaN
# 386        225.9        NaN         NaN
# 387        226.8        NaN         NaN
# 388        213.2        NaN         NaN
# 389        167.8        NaN         NaN
# 390        191.4        NaN         NaN
# 391        147.4        NaN         NaN
# 392          NaN        NaN         NaN
# 393          NaN        NaN         NaN
# 394          NaN        NaN         NaN
# 395        222.7        NaN         NaN
# 396        243.1        NaN         NaN
# 397        215.5        NaN         NaN
# 398        217.3        NaN         NaN
# 399        198.2        NaN         NaN
# 400        248.1        NaN         NaN
# 401        155.1        NaN         NaN
# 402        271.7        NaN         NaN
# 403        255.4        NaN         NaN
# 404        249.0        NaN         NaN
# 405        176.9        NaN         NaN
# 406        155.6        NaN         NaN
# 407        210.0        NaN         NaN
# 408        247.2        NaN         NaN
# 409        249.0        NaN         NaN
# 410        151.0        NaN         NaN
# 411        195.0        NaN         NaN
# 412        193.7        NaN         NaN
# 413        228.2        NaN         NaN
# 414        170.1        NaN         NaN
# 415        210.0        NaN         NaN
# 416        209.6        NaN         NaN
# 417        212.3        NaN         NaN
# 418        211.4        NaN         NaN
# 419        207.7        NaN         NaN
# 420        214.5        NaN         NaN
# 421        222.7        NaN         NaN
# 422        146.5        NaN         NaN
# 423        262.2        NaN         NaN
# 424        243.1        NaN         NaN
# 425        186.4        NaN         NaN
# 426        323.0        NaN         NaN
# 427        186.0        NaN         NaN
# 428        206.8        NaN         NaN
# 429        206.4        NaN         NaN
# 430          NaN        NaN         NaN
# 431        196.4        NaN         NaN
# 432        193.2        NaN         NaN
# 433        166.9        NaN         NaN
# 434        205.0        NaN         NaN
# 435        204.6        NaN         NaN
# 436        197.3        NaN         NaN
# 437        212.7        NaN         NaN
# 438        211.8        NaN         NaN
# 440        205.0        NaN         NaN
# 441        156.5        NaN         NaN
# 442        195.5        NaN         NaN
# 443        200.0        NaN         NaN
# 444        210.5        NaN         NaN
# 445        210.9        NaN         NaN
# 446        169.2        NaN         NaN
# 447        201.8        NaN         NaN
# 448        204.6        NaN         NaN
# 449        256.3        NaN         NaN
# 450        212.3        NaN         NaN
# 451        191.0        NaN         NaN
# 452        204.6        NaN         NaN
# 453        215.0        NaN         NaN
# 454        203.7        NaN         NaN
# 455        193.2        NaN         NaN
# 456        210.9        NaN         NaN
# 457        237.7        NaN         NaN
# 458        241.8        NaN         NaN
# 459          NaN        NaN         NaN
# 460        213.6        NaN         NaN
# 461        196.4        NaN         NaN
# 462        201.8        NaN         NaN
# 463        203.2        NaN         NaN
# 464        213.6        NaN         NaN
# 465        210.5        NaN         NaN
# 466        201.4        NaN         NaN
# 467        203.7        NaN         NaN
# 468        212.7        NaN         NaN
# 469        218.6        NaN         NaN
# 470        198.2        NaN         NaN
# 471        175.1        NaN         NaN
# 472        165.1        NaN         NaN
# 473        211.4        NaN         NaN
# 474        208.7        NaN         NaN
# 475        164.7        NaN         NaN
# 476        240.0        NaN         NaN
# 477        254.5        NaN         NaN
# 478        226.3        NaN         NaN
# 479        173.7        NaN         NaN
# 480        210.9        NaN         NaN
# 481          NaN        NaN         NaN
# 482        192.8        NaN         NaN
# 483        171.0        NaN         NaN
# 484          NaN        NaN         NaN
# 485        251.7        NaN         NaN
# 486        195.0        NaN         NaN
# 487        197.3        NaN         NaN
# 488          NaN        NaN         NaN
# 489        215.0        NaN         NaN
# 490        188.7        NaN         NaN
# 491        188.2        NaN         NaN
# 492        182.8        NaN         NaN
# 523        201.8        NaN         NaN
# 524        230.0        NaN         NaN
# 525        174.2        NaN         NaN
# 526        197.3        NaN         NaN
# 527        227.2        NaN         NaN
# 528        206.4        NaN         NaN
# 529        201.4        NaN         NaN
# 530        210.9        NaN         NaN
# 531        151.0        NaN         NaN
# 532        198.2        NaN         NaN
# 533        227.7        NaN         NaN
# 534        230.9        NaN         NaN
# 535          NaN        NaN         NaN
# 536        220.0        NaN         NaN
# 537        201.8        NaN         NaN
# 538        229.5        NaN         NaN
# 539        195.5        NaN         NaN
# 540        185.5        NaN         NaN
# 541        163.7        NaN         NaN
# 542        187.8        NaN         NaN
# 543        147.0        NaN         NaN
# 544        218.6        NaN         NaN
# 545        207.7        NaN         NaN
# 546        234.5        NaN         NaN
# 547        216.4        NaN         NaN
# 548        231.3        NaN         NaN
# 549        176.9        NaN         NaN
# 550        217.3        NaN         NaN
# 551        203.7        NaN         NaN
# 552        235.0        NaN         NaN
# 553        156.0        NaN         NaN
# 554          NaN        NaN         NaN
# 555        147.0        NaN         NaN
# 556        205.0        NaN         NaN
# 557        246.8        NaN         NaN
# 558        238.6        NaN         NaN
# 559        163.7        NaN         NaN
# 560        186.9        NaN         NaN
# 561        188.2        NaN         NaN
# 562        191.4        NaN         NaN
# 563        174.6        NaN         NaN
# 564        260.8        NaN         NaN
# 565        202.8        NaN         NaN
# 566        202.8        NaN         NaN
# 567        209.6        NaN         NaN
# 568        212.3        NaN         NaN
# 569        215.0        NaN         NaN
# 570          NaN        NaN         NaN
# 571        139.3        NaN         NaN
# 572        239.5        NaN         NaN
# 573        196.0        NaN         NaN
# 575        174.2        NaN         NaN
# 576        207.7        NaN         NaN
# 577        197.8        NaN         NaN
# 578        198.7        NaN         NaN
# 579        156.5        NaN         NaN
# 580        174.2        NaN         NaN
# 581        184.6        NaN         NaN
# 582        205.5        NaN         NaN
# 583        204.6        NaN         NaN
# 584        198.7        NaN         NaN
# 585        197.3        NaN         NaN
# 586        223.2        NaN         NaN
# 587        232.7        NaN         NaN
# 624        152.4        NaN         NaN
# 625        217.3        NaN         NaN
# 626        188.2        NaN         NaN
# 627        200.0        NaN         NaN
# 628        189.6        NaN         NaN
# 629        216.4        NaN         NaN
# 630        220.4        NaN         NaN
# 631        174.2        NaN         NaN
# 632        179.6        NaN         NaN
# 633        203.2        NaN         NaN
# 634        212.7        NaN         NaN
# 635        173.3        NaN         NaN
# 636        201.8        NaN         NaN
# 637        198.7        NaN         NaN
# 638        197.8        NaN         NaN
# 639        205.5        NaN         NaN
# 640        178.3        NaN         NaN
# 641        205.5        NaN         NaN
# 642        222.7        NaN         NaN
# 643        224.5        NaN         NaN
# 644        209.6        NaN         NaN
# 645        190.5        NaN         NaN
# 646        200.9        NaN         NaN
# 647        211.8        NaN         NaN
# 648          NaN        NaN         NaN
# 649        202.3        NaN         NaN
# 650        211.4        NaN         NaN
# 651        171.5        NaN         NaN
# 652        225.4        NaN         NaN
# 653        210.9        NaN         NaN
# 654        205.5        NaN         NaN
# 655        237.7        NaN         NaN
# 656        210.9        NaN         NaN
# 657        180.1        NaN         NaN
# 658        178.7        NaN         NaN
# 659        224.5        NaN         NaN
# 660        218.6        NaN         NaN
# 661        155.6        NaN         NaN
# 662        223.2        NaN         NaN
# 664        205.9        NaN         NaN
# 665        204.1        NaN         NaN
# 666        219.5        NaN         NaN
# 667        181.4        NaN         NaN
# 668        224.5        NaN         NaN
# 669        196.9        NaN         NaN
# 670        192.8        NaN         NaN
# 671        163.3        NaN         NaN
# 672        235.9        NaN         NaN
# 673        208.7        NaN         NaN
# 674        199.6        NaN         NaN
# 675        221.8        NaN         NaN
# 676        217.7        NaN         NaN
# 677        183.7        NaN         NaN
# 678        168.7        NaN         NaN
# C:\Users\gsant\AppData\Local\Temp\ipykernel_50696\3221132384.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data["Place"] = merged_data["Place"].fillna("Unranked")

# %%
# Clean place data
placement_new = pd.DataFrame.copy(merged_data)
placement_new = placement_new.dropna(subset=["Place"])
unranked = merged_data[merged_data["Place"] == "Unranked"]
placement_new = placement_new[placement_new.Place != "Unranked"]

tied_cases = placement_new["Place"].str.contains('T')
tied_cases = tied_cases.fillna(False)
tied = placement_new[tied_cases]
tied["Place"] = tied["Place"].str[:-2]
placement_new = placement_new[~tied_cases]
placement_new = pd.concat([placement_new, tied], ignore_index = True)

placement_new["Place"] = placement_new["Place"].astype(int)
placement_new = placement_new.reset_index(drop = True)
adjustment = pd.DataFrame.copy(placement_new)
adjustment["Place"] = pd.qcut(adjustment["Place"],q=4, labels=labels)
# for i in range(len(placement_new)):
#     if placement_new.iloc[i]["Place"] <= 30:
#         adjustment.at[i,"Place"] = "<=30"
#     elif placement_new.iloc[i]["Place"] <= 60:
#         adjustment.at[i,"Place"] = "<=60"
#     elif placement_new.iloc[i]["Place"] <= 90:
#         adjustment.at[i,"Place"] = "<=90"
#     else:
#         adjustment.at[i,"Place"] = ">90"

placement_new["Place"] = adjustment["Place"]
placement_new = placement_new.replace("DNF", np.nan)

#print(placement_new["Place"].value_counts())
# Out:
# C:\Users\gsant\AppData\Local\Temp\ipykernel_50696\2364201400.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tied_cases = tied_cases.fillna(False)
# C:\Users\gsant\AppData\Local\Temp\ipykernel_50696\2364201400.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tied["Place"] = tied["Place"].str[:-2]

# %%
# Clean cost data
cost_new = pd.DataFrame.copy(placement_new)
cost_new["Adjusted Cost"] = (cost_new["Adjusted Cost"].str.replace('[$, ]', '', regex=True).astype(float))
clean_data = pd.DataFrame.copy(cost_new)

# %%
# Ready acceleration for predictions
acceleration_prediction_data = clean_data.reset_index()
# for i in range(len(acceleration_prediction_data)):
#     if acceleration_prediction_data.iloc[i]["Acceleration Score"] > 80:
#         acceleration_prediction_data.at[i,"Acceleration Score"] = ">80"
#     elif acceleration_prediction_data.iloc[i]["Acceleration Score"] >= 65:
#         acceleration_prediction_data.at[i,"Acceleration Score"] = ">=65"
#     elif acceleration_prediction_data.iloc[i]["Acceleration Score"] >= 50:
#         acceleration_prediction_data.at[i,"Acceleration Score"] = ">=50"
#     elif not pd.isna(acceleration_prediction_data.iloc[i]["Acceleration Score"]):
#         acceleration_prediction_data.at[i,"Acceleration Score"] = "<50"
acceleration_prediction_data["Acceleration Score"] = pd.qcut(acceleration_prediction_data["Acceleration Score"],q=4, labels=labels)

clean_data["Acceleration Score"] = acceleration_prediction_data["Acceleration Score"]
print(clean_data["Acceleration Score"].value_counts())
# Out:
# Acceleration Score
# Quartile 1    86
# Quartile 2    86
# Quartile 4    85
# Quartile 3    84
# Name: count, dtype: int64

# %%
# Ready skidpad for predictions
skidpad_prediction_data = clean_data.reset_index()
# for i in range(len(skidpad_prediction_data)):
#     if skidpad_prediction_data.iloc[i]["Skid Pad Score"] >= 55:
#         skidpad_prediction_data.at[i,"Skid Pad Score"] = ">=55"
#     elif skidpad_prediction_data.iloc[i]["Skid Pad Score"] >= 45:
#         skidpad_prediction_data.at[i,"Skid Pad Score"] = ">=45"
#     elif skidpad_prediction_data.iloc[i]["Skid Pad Score"] >= 25:
#         skidpad_prediction_data.at[i,"Skid Pad Score"] = ">=25"
#     elif not pd.isna(skidpad_prediction_data.iloc[i]["Skid Pad Score"]):
#         skidpad_prediction_data.at[i,"Skid Pad Score"] = "<25"
skidpad_prediction_data["Skid Pad Score"] = pd.qcut(skidpad_prediction_data["Skid Pad Score"],q=4, labels=labels)

clean_data["Skid Pad Score"] = skidpad_prediction_data["Skid Pad Score"]
print(clean_data["Skid Pad Score"].value_counts())
# Out:
# Skid Pad Score
# Quartile 1    90
# Quartile 2    88
# Quartile 4    88
# Quartile 3    86
# Name: count, dtype: int64

# %%
# Ready Autocross for predictions
autocross_prediction_data = clean_data.reset_index()

# for i in range(len(autocross_prediction_data)):
#     if autocross_prediction_data.iloc[i]["Autocross Score"] > 90:
#         autocross_prediction_data.at[i,"Autocross Score"] = ">90"
#     elif autocross_prediction_data.iloc[i]["Autocross Score"] >= 65:
#         autocross_prediction_data.at[i,"Autocross Score"] = ">=65"
#     elif autocross_prediction_data.iloc[i]["Autocross Score"] >= 40:
#         autocross_prediction_data.at[i,"Autocross Score"] = ">=40"
#     elif not pd.isna(autocross_prediction_data.iloc[i]["Autocross Score"]):
#         autocross_prediction_data.at[i,"Autocross Score"] = "<40"
autocross_prediction_data["Autocross Score"] = pd.qcut(acceleration_prediction_data["Autocross Score"],q=4, labels=labels)

clean_data["Autocross Score"] = autocross_prediction_data["Autocross Score"]
print(clean_data["Autocross Score"].value_counts())
# Out:
# Autocross Score
# Quartile 1    90
# Quartile 2    89
# Quartile 3    89
# Quartile 4    89
# Name: count, dtype: int64

# %%
# Ready Endurance for predictions
endurance_prediction_data = clean_data.reset_index()
# for i in range(len(endurance_prediction_data)):
#     if endurance_prediction_data.iloc[i]["Endurance Score"] > 150:
#         endurance_prediction_data.at[i,"Endurance Score"] = ">150"
#     elif endurance_prediction_data.iloc[i]["Endurance Score"] >= 75:
#         endurance_prediction_data.at[i,"Endurance Score"] = ">=75"
#     elif endurance_prediction_data.iloc[i]["Endurance Score"] >= 10:
#         endurance_prediction_data.at[i,"Endurance Score"] = ">=10"
#     elif not pd.isna(endurance_prediction_data.iloc[i]["Endurance Score"]):
#         endurance_prediction_data.at[i,"Endurance Score"] = "<10"
endurance_prediction_data["Endurance Score"] = pd.qcut(endurance_prediction_data["Endurance Score"],q=4, labels=labels)

clean_data["Endurance Score"] = endurance_prediction_data["Endurance Score"]
print(clean_data["Endurance Score"].value_counts())
#print(clean_data)
# Out:
# Endurance Score
# Quartile 1    94
# Quartile 4    87
# Quartile 2    85
# Quartile 3    83
# Name: count, dtype: int64

# %%
clean_data.replace("DNA", "", inplace=True)
filepath = Path("fsae_data/clean_data/ultra_clean_condensed.csv")
clean_data.to_csv(filepath, index= False)
# Out:
# 0         NaN
# 1       4.828
# 2       4.356
# 3       4.374
# 4         NaN
# 5        4.38
# 6         NaN
# 7       4.981
# 8       4.687
# 9       4.992
# 10      7.833
# 11      4.468
# 12      4.562
# 13      4.169
# 14       5.02
# 15      4.829
# 16      4.471
# 17        NaN
# 18      4.805
# 19        NaN
# 20      4.429
# 21        NaN
# 22       4.56
# 23      5.054
# 24        NaN
# 25        NaN
# 26      4.994
# 27      4.963
# 28      4.554
# 29       4.34
# 30      4.518
# 31      5.055
# 32        NaN
# 33      4.564
# 34        NaN
# 35      4.307
# 36       7.61
# 37        NaN
# 38        NaN
# 39      4.558
# 40      4.364
# 41        NaN
# 42        NaN
# 43        NaN
# 44       4.26
# 45      4.585
# 46      4.649
# 47       4.67
# 48        NaN
# 49      4.612
# 50        NaN
# 51       4.73
# 52      5.239
# 53      4.324
# 54        NaN
# 55        NaN
# 56      4.777
# 57        NaN
# 58      8.901
# 59       4.81
# 60      4.862
# 61        NaN
# 62        NaN
# 63      4.504
# 64        NaN
# 65       4.32
# 66      4.879
# 67      4.799
# 68      4.923
# 69        NaN
# 70      4.661
# 71      5.131
# 72        NaN
# 73      5.232
# 74      4.487
# 75        NaN
# 76      4.854
# 77      4.229
# 78      4.622
# 79        NaN
# 80      5.338
# 81      4.264
# 82        NaN
# 83        NaN
# 84      4.377
# 85      4.849
# 86      4.286
# 87      5.044
# 88       4.97
# 89      4.902
# 90      4.271
# 91      4.546
# 92        NaN
# 93        NaN
# 94      4.306
# 95      4.384
# 96      4.501
# 97      4.421
# 98      4.797
